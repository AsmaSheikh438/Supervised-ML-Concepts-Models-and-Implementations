# %% [markdown]
# ![train test split - Yahoo India Image Search results - Google Chrome 28-11-2024 16_38_52.png](attachment:e7daee4b-da3e-4293-bbd9-0e17f70a4079.png)

# %% [markdown]
# ![train test split - Yahoo India Image Search results - Google Chrome 28-11-2024 16_47_10.png](attachment:6200f1bc-7d86-495e-ab97-e69c2338bfc6.png)

# %%
import pandas as pd

# %%
dataset = pd.read_csv('BostonHousing.csv')
dataset.head(5)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
input_data = dataset.iloc[:,:-1]  # select all column name and left last column
input_data
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
# we can see clearly now the last column name 'medv' is removed now in this data 
# we removed that part for our testing purpose

# %%
output_data = dataset['medv']
output_data
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
# after splitting data into input and output data we have to perform train, test ,splitting

# %%
from sklearn.model_selection import train_test_split

# %%
# now this train test split will give you 4 output....
# giving input data in tts = return 2 output train & test
# giving output data in tts = return 2 output train & test   
# total = 4 outputs

# %%
x_train, x_test, y_train, y_test = train_test_split(input_data, output_data,test_size= 0.25)

# %%
x_test
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 91   0.03932   0.0   3.41     0  0.489  6.405  73.9  3.0921    2  270
# 218  0.11069   0.0  13.89     1  0.550  5.951  93.8  2.8893    5  276
# 294  0.08199   0.0  13.92     0  0.437  6.009  42.3  5.5027    4  289
# 235  0.33045   0.0   6.20     0  0.507  6.086  61.5  3.6519    8  307
# 251  0.21409  22.0   5.86     0  0.431  6.438   8.9  7.3967    7  330
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 39   0.02763  75.0   2.95     0  0.428  6.595  21.8  5.4011    3  252
# 325  0.19186   0.0   7.38     0  0.493  6.431  14.7  5.4159    5  287
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 147  2.36862   0.0  19.58     0  0.871  4.926  95.7  1.4608    5  403
#
#      ptratio       b  lstat
# 91      17.8  393.55   8.20
# 218     16.4  396.90  17.92
# 294     16.0  396.90  10.40
# ...

# %%
x_train
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 180  0.06588   0.0   2.46     0  0.488  7.765  83.3  2.7410    3  193
# 319  0.47547   0.0   9.90     0  0.544  6.113  58.8  4.0019    4  304
# 112  0.12329   0.0  10.01     0  0.547  5.913  92.9  2.3534    6  432
# 113  0.22212   0.0  10.01     0  0.547  6.092  95.4  2.5480    6  432
# 424  8.79212   0.0  18.10     0  0.584  5.565  70.6  2.0635   24  666
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 22   1.23247   0.0   8.14     0  0.538  6.142  91.7  3.9769    4  307
# 241  0.10612  30.0   4.93     0  0.428  6.095  65.1  6.3361    6  300
# 487  4.83567   0.0  18.10     0  0.583  5.905  53.2  3.1523   24  666
# 115  0.17134   0.0  10.01     0  0.547  5.928  88.2  2.4631    6  432
# 118  0.13058   0.0  10.01     0  0.547  5.872  73.1  2.4775    6  432
#
#      ptratio       b  lstat
# 180     17.8  395.56   7.56
# 319     18.4  396.23  12.73
# 112     17.8  394.95  16.21
# ...

# %%
y_test
# Out:
# 91     22.0
# 218    21.5
# 294    21.7
# 235    24.0
# 251    24.8
#        ...
# 39     30.8
# 325    24.6
# 501    22.4
# 2      34.7
# 147    14.6
# Name: medv, Length: 127, dtype: float64

# %%
# check our data is split into 25% or not
dataset.shape
# Out:
# (506, 14)

# %%
x_train.shape,y_train.shape
# Out:
# ((379, 13), (379,))

# %%
x_test.shape,y_test.shape
# Out:
# ((127, 13), (127,))

# %%
# yes our data split into training and testing
