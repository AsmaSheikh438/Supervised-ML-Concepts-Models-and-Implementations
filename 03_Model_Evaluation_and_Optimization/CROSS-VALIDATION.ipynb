# %% [markdown]
# ![IMG-20241207-WA0014.jpg](attachment:f5db9a2f-7c5c-4432-a4fd-01027eaa5fbe.jpg)

# %% [markdown]
# ![cross validation - Yahoo India Image Search results - Google Chrome 07-12-2024 19_45_12.png](attachment:d5e948b8-b1d9-4d43-afdd-f5504be56a4c.png)

# %% [markdown]
# ![IMG-20241207-WA0013.jpg](attachment:59bdb29c-a93c-4728-9a3d-addbc87daa8e.jpg)

# %% [markdown]
# ![IMG-20241207-WA0012.jpg](attachment:842b3dde-1f70-49c5-a123-24ef65ace519.jpg)

# %% [markdown]
# ![cross validation - Yahoo India Image Search results - Google Chrome 07-12-2024 19_22_17.png](attachment:6d06e1ec-9395-4000-ad63-cdfda494585a.png)

# %% [markdown]
# ![IMG-20241207-WA0011.jpg](attachment:665184e6-c8f9-4b73-9838-f2698b1aaddc.jpg)

# %% [markdown]
# ![cross validation - Yahoo India Image Search results - Google Chrome 07-12-2024 19_59_19.png](attachment:1206a4b0-3e85-464d-9ce5-db535f2d11cb.png)

# %% [markdown]
# ![IMG-20241207-WA0009.jpg](attachment:92fc31e0-7495-44cb-b39e-8c3841459905.jpg)

# %% [markdown]
# ![cross validation - Yahoo India Image Search results - Google Chrome 07-12-2024 20_03_17.png](attachment:5469aa64-bee9-4937-8c95-3ce4032980fe.png)

# %% [markdown]
# ![IMG-20241207-WA0010.jpg](attachment:cf8da856-7f3b-495f-8efc-9a859641849f.jpg)

# %% [markdown]
# ![cross validation - Yahoo India Image Search results - Google Chrome 07-12-2024 20_04_40.png](attachment:8e4e9c7c-d6b2-43ee-bff6-f92210c91490.png)
