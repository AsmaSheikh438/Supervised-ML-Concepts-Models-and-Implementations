# %% [markdown]
# ### Confusion Matrics :
# #### (for binary class classification)
# * A confusion matrix is a simple and useful tool for understanding the performance of a classification model, like one used in machine learning or statistics.
# * A confusion matrix is used to evaluate the performance of a classification model by comparing actual and predicted labels.
# * It helps you evaluate how well your model is doing in categorizing things correctly.
# * It also known as the error matrix.

# %% [markdown]
# ### The Confusion Matrix Structure
# Let’s learn about the basic structure of a confusion matrix, using the example of identifying an email as spam or not spam.
#
# #### True Positive (TP) - Your model predicted the positive class. For example, identifying a spam email as spam.
# #### True Negative (TN) - Your model correctly predicted the negative class. For example, identifying a regular email as not spam.
# #### False Positive (FP) - Your model incorrectly predicted the positive class. For example, identifying a regular email as spam.
# #### False Negative (FN) - Your model incorrectly predicted the negative class. For example, identifying a spam email as a regular email.

# %% [markdown]
# #### 👉 True Positive: The number of times our actual positive values are equal to the predicted positive. You predicted a positive value, and it is correct.
# #### 👉 False Positive: The number of times our model wrongly predicts negative values as positives. You predicted a negative value, and it is actually positive.
# #### 👉 True Negative: The number of times our actual negative values are equal to predicted negative values. You predicted a negative value, and it is actually negative.
# #### 👉 False Negative: The number of times our model wrongly predicts negative values as positives. You predicted a negative value, and it is actually positive.

# %% [markdown]
# ![One-vs-Rest strategy for Multi-Class Classification - GeeksforGeeks - Google Chrome 04-12-2024 13_36_27.png](attachment:3488260f-8765-494e-9b30-34fe21c0a3ea.png)

# %% [markdown]
# ![One-vs-Rest strategy for Multi-Class Classification - GeeksforGeeks - Google Chrome 04-12-2024 14_06_12.png](attachment:0f0e7632-a3fd-433a-9f1d-b379975167ce.png)

# %% [markdown]
# ![One-vs-Rest strategy for Multi-Class Classification - GeeksforGeeks - Google Chrome 04-12-2024 14_06_29.png](attachment:7cd9d5be-fb08-478d-bfa2-dbd3877b20f0.png)

# %% [markdown]
# ![One-vs-Rest strategy for Multi-Class Classification - GeeksforGeeks - Google Chrome 04-12-2024 14_06_45.png](attachment:3ea6fa86-bf79-482a-80de-097b2c613b18.png)

# %% [markdown]
# ![One-vs-Rest strategy for Multi-Class Classification - GeeksforGeeks - Google Chrome 04-12-2024 14_06_57.png](attachment:84740a14-f017-43c6-a6e6-fe110530962e.png)

# %% [markdown]
# ![WhatsApp Image 2024-12-04 at 14.31.47_81dba10d.jpg](attachment:96bb67a4-46c7-4b7f-ae99-2256229def27.jpg)

# %% [markdown]
# ![WhatsApp Image 2024-12-04 at 14.36.17_19ce02ba.jpg](attachment:41e2df87-fcf9-44e2-b2b2-d8f38d6ac484.jpg)

# %% [markdown]
# ![WhatsApp Image 2024-12-04 at 14.48.29_bb82066c.jpg](attachment:e1d92516-cff6-410b-b910-6b403fb36bfa.jpg)

# %% [markdown]
# ### Model B is a good model because it only 10 not spam mail to spam but model A send 30

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset= pd.read_csv('placement.csv')
dataset.head(5)
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
x= dataset.iloc[:,:-1]
y= dataset['placed']

# %%
# now splitting of data into training and testing
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
LR.score(x_test,y_test)*100
# Out:
# 54.0

# %%
# not good accuracy

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

# %%
cf = confusion_matrix(y_test,LR.predict(x_test))

# %%
sns.heatmap(cf,annot=True)
plt.show()

# %%
precision_score(y_test,LR.predict(x_test))*100
# Out:
# 50.505050505050505

# %%
# not good accuracy

# %%
recall_score(y_test,LR.predict(x_test))*100
# Out:
# 53.76344086021505

# %%
f1_score(y_test,LR.predict(x_test))*100
# Out:
# 52.083333333333336

# %% [markdown]
# ### Here, we can see all these values are not high but as we know that for good model these three values score should be high as it somewhere reduce the FN & FP values
