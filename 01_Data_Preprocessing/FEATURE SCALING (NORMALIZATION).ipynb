# %% [markdown]
# ## (NORMALIZATION) Min-Max Scaling

# %% [markdown]
# ### Normalization:
# This method scales each feature so that all values are within the range of 0 and 1. It achieves this by subtracting the minimum value of the feature and dividing by the range (difference between maximum and minimum values).
# Normalization is a fundamental technique in machine learning that transforms numerical features to a standard scale, typically between 0 and 1.
#
# This process ensures that all features contribute equally to the analysis, preventing those with larger numerical ranges from dominating the model’s outcomes.
#
# Understanding Normalization
#
# Normalization is achieved through a simple formula:

# %% [markdown]
# ![normalization formuls - Yahoo India Image Search results - Google Chrome 27-11-2024 13_20_29.png](attachment:3d2e798d-4eda-4fe9-ac8d-82e259ee34cf.png)

# %%
import pandas as pd
import  seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('loan_test.csv')
dataset.head(5)
# Out:
#   Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0   Male     Yes          0      Graduate            No            572000
# 1   Male     Yes          1      Graduate            No            307600
# 2   Male     Yes          2      Graduate            No            500000
# 3   Male     Yes          2      Graduate            No            234000
# 4   Male      No          0  Not Graduate            No            327600
#
#    Coapplicant_Income  Loan_Amount   Term  Credit_History   Area
# 0                   0     11000000  360.0             1.0  Urban
# 1              150000     12600000  360.0             1.0  Urban
# 2              180000     20800000  360.0             1.0  Urban
# 3              254600     10000000  360.0             NaN  Urban
# 4                   0      7800000  360.0             1.0  Urban

# %%
# checking null values
dataset.isnull().sum()
# Out:
# Gender                11
# Married                0
# Dependents            10
# Education              0
# Self_Employed         23
# Applicant_Income       0
# Coapplicant_Income     0
# Loan_Amount            0
# Term                   6
# Credit_History        29
# Area                   0
# dtype: int64

# %%
dataset.describe()
# Out:
#        Applicant_Income  Coapplicant_Income   Loan_Amount        Term  \
# count      3.670000e+02        3.670000e+02  3.670000e+02  361.000000
# mean       4.805599e+05        1.569578e+05  1.342779e+07  342.537396
# std        4.910685e+05        2.334232e+05  6.296143e+06   65.156643
# min        0.000000e+00        0.000000e+00  0.000000e+00    6.000000
# 25%        2.864000e+05        0.000000e+00  1.000000e+07  360.000000
# 50%        3.786000e+05        1.025000e+05  1.250000e+07  360.000000
# 75%        5.060000e+05        2.430500e+05  1.575000e+07  360.000000
# max        7.252900e+06        2.400000e+06  5.500000e+07  480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
# graphical nature
sns.distplot(dataset['Coapplicant_Income'])
plt.show()
# Out:
# C:\Users\asmas\AppData\Local\Temp\ipykernel_2380\3041144487.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['Coapplicant_Income'])

# %% [markdown]
# #### when we do scaling on data ,the outliers remains same but the magnitude will get reduced

# %%
# performing min-max scaling (Normalization)
from sklearn.preprocessing import MinMaxScaler

# %%
ms = MinMaxScaler()
ms.fit(dataset[['Coapplicant_Income']])  # It works on two dimentional (2D) data [[ ]]
# Out:
# MinMaxScaler()

# %%
ms.transform(dataset[['Coapplicant_Income']])
# Out:
# array([[0.        ],
#        [0.0625    ],
#        [0.075     ],
#        [0.10608333],
#        [0.        ],
#        [0.14258333],
#        [0.        ],
#        [0.        ],
#        [0.        ],
#        [0.1       ],
#        [0.        ],
#        [0.06316667],
#        [0.        ],
#        [0.        ],
#        [0.        ],
#        [0.        ],
#        [0.1215    ],
#        [0.013875  ],
#        [0.32983333],
#        [0.14458333],
#        [0.0675    ],
#        [0.        ],
#        [0.        ],
#        [0.        ],
#        [0.1825    ],
#        [1.        ],
#        [0.05208333],
#        [0.15625   ],
#        [0.03470833],
#        [0.09925   ],
#        [0.        ],
#        [0.03416667],
#        [0.070125  ],
#        [0.11283333],
#        [0.06420833],
#        [0.        ],
#        [0.167875  ],
#        [0.11633333],
#        [0.        ],
#        [0.08179167],
#        [0.03408333],
#        [0.        ],
#        [0.08433333],
# ...

# %%
dataset['Coapplicant_Income_min'] = ms.transform(dataset[['Coapplicant_Income']])

# %%
dataset.head(5)
# Out:
#   Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0   Male     Yes          0      Graduate            No            572000
# 1   Male     Yes          1      Graduate            No            307600
# 2   Male     Yes          2      Graduate            No            500000
# 3   Male     Yes          2      Graduate            No            234000
# 4   Male      No          0  Not Graduate            No            327600
#
#    Coapplicant_Income  Loan_Amount   Term  Credit_History   Area  \
# 0                   0     11000000  360.0             1.0  Urban
# 1              150000     12600000  360.0             1.0  Urban
# 2              180000     20800000  360.0             1.0  Urban
# 3              254600     10000000  360.0             NaN  Urban
# 4                   0      7800000  360.0             1.0  Urban
#
#    Coapplicant_Income_min
# 0                0.000000
# 1                0.062500
# 2                0.075000
# ...

# %%
# checking dataset nature got changed or not
# Assuming `dataset` is a DataFrame and 'Coapplicant_Income' is a column in it.

plt.figure(figsize=(12, 6))

# Before Plot
plt.subplot(1, 2, 1)  
plt.title('Before')
sns.distplot(dataset['Coapplicant_Income'])

# After Plot
plt.subplot(1, 2, 2) 
plt.title('After')
sns.distplot(dataset['Coapplicant_Income_min']) 

plt.show()
# Out:
# C:\Users\asmas\AppData\Local\Temp\ipykernel_2380\2738097407.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['Coapplicant_Income'])
# C:\Users\asmas\AppData\Local\Temp\ipykernel_2380\2738097407.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# #### here, we can see the data magnitude get reduced in between the range of 0-1
