# %%
import pandas as pd

# %%
df= pd.DataFrame({'name':['asma','cow','cat','dog','black']})
df
# Out:
#     name
# 0   asma
# 1    cow
# 2    cat
# 3    dog
# 4  black

# %%
# now encode this dataset using scikit-learn liberary
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit_transform(df['name'])
# Out:
# array([0, 3, 2, 4, 1])

# %%
df['en_name'] = le.fit_transform(df['name'])

# %%
df
# Out:
#     name  en_name
# 0   asma        0
# 1    cow        3
# 2    cat        2
# 3    dog        4
# 4  black        1

# %%
dataset= pd.read_csv('loan_test.csv')
dataset.head(5)
# Out:
#   Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0   Male     Yes          0      Graduate            No            572000
# 1   Male     Yes          1      Graduate            No            307600
# 2   Male     Yes          2      Graduate            No            500000
# 3   Male     Yes          2      Graduate            No            234000
# 4   Male      No          0  Not Graduate            No            327600
#
#    Coapplicant_Income  Loan_Amount   Term  Credit_History   Area
# 0                   0     11000000  360.0             1.0  Urban
# 1              150000     12600000  360.0             1.0  Urban
# 2              180000     20800000  360.0             1.0  Urban
# 3              254600     10000000  360.0             NaN  Urban
# 4                   0      7800000  360.0             1.0  Urban

# %%
la = LabelEncoder()
la.fit(dataset['Area'])
# Out:
# LabelEncoder()

# %%
la.transform(dataset['Area'])
# Out:
# array([2, 2, 2, 2, 2, 2, 1, 0, 2, 1, 2, 1, 2, 1, 1, 2, 2, 1, 2, 1, 2, 2,
#        2, 2, 2, 0, 2, 2, 1, 2, 1, 2, 1, 2, 2, 1, 2, 2, 2, 2, 2, 2, 1, 1,
#        2, 2, 2, 1, 2, 1, 2, 1, 1, 2, 2, 2, 0, 1, 1, 1, 1, 2, 1, 0, 2, 1,
#        1, 1, 1, 0, 1, 1, 2, 0, 1, 2, 2, 0, 1, 2, 2, 2, 0, 0, 1, 0, 2, 1,
#        1, 0, 0, 0, 1, 1, 1, 1, 2, 1, 2, 1, 0, 1, 2, 0, 1, 1, 2, 0, 1, 2,
#        1, 1, 2, 1, 0, 1, 1, 0, 2, 0, 2, 0, 2, 0, 2, 1, 2, 2, 2, 1, 2, 0,
#        0, 2, 2, 2, 0, 0, 1, 1, 0, 0, 2, 1, 0, 2, 1, 0, 1, 2, 2, 2, 0, 2,
#        0, 1, 2, 0, 1, 0, 0, 1, 2, 0, 0, 1, 2, 2, 1, 0, 0, 0, 0, 2, 0, 0,
#        2, 0, 0, 2, 1, 1, 2, 0, 2, 1, 1, 1, 0, 0, 0, 2, 0, 0, 1, 2, 1, 0,
#        2, 0, 0, 2, 2, 1, 1, 1, 1, 1, 2, 0, 2, 0, 1, 0, 0, 2, 1, 0, 0, 2,
#        2, 0, 2, 0, 1, 2, 2, 0, 0, 2, 1, 2, 0, 1, 2, 2, 1, 0, 1, 2, 2, 1,
#        1, 0, 1, 1, 2, 2, 1, 0, 2, 1, 1, 2, 2, 0, 0, 2, 0, 0, 1, 1, 0, 0,
#        0, 1, 2, 0, 0, 0, 2, 0, 1, 1, 1, 1, 2, 1, 1, 1, 1, 0, 2, 0, 2, 2,
# ...

# %%
dataset['Area'].unique()
# Out:
# array(['Urban', 'Semiurban', 'Rural'], dtype=object)

# %%
# replacing of Area data with encoding data in our dataset
dataset['Area'] = la.transform(dataset['Area'])

# %%
dataset.head(10)
# Out:
#    Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0    Male     Yes          0      Graduate            No            572000
# 1    Male     Yes          1      Graduate            No            307600
# 2    Male     Yes          2      Graduate            No            500000
# 3    Male     Yes          2      Graduate            No            234000
# 4    Male      No          0  Not Graduate            No            327600
# 5    Male     Yes          0  Not Graduate           Yes            216500
# 6  Female      No          1  Not Graduate            No            222600
# 7    Male     Yes          2  Not Graduate            No            388100
# 8    Male     Yes          2      Graduate           NaN           1363300
# 9    Male      No          0  Not Graduate            No            240000
#
#    Coapplicant_Income  Loan_Amount   Term  Credit_History  Area
# 0                   0     11000000  360.0             1.0     2
# ...
