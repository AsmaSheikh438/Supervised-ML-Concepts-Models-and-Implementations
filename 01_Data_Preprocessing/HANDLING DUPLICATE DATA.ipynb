# %% [markdown]
# ### What is Data Duplication?
# Data deduplication is the process of reducing the amount of duplicate data stored on a system. By identifying and removing duplicate data, you can reduce the amount of storage space needed to store your data. This is especially useful for large datasets that contain a lot of redundant data, such as backups.

# %% [markdown]
# ### Example

# %% [markdown]
# ![duplicate data - Yahoo India Image Search results - Google Chrome 27-11-2024 14_26_54.png](attachment:f80eb330-267b-4636-b0e1-49f948bf0b75.png)

# %%
import pandas as pd

# %%
# creating dataset
data= {'name':['a','b','c','d','a','c'],'eng':[8,7,5,8,8,5],'hindi':[2,3,4,5,2,6]}

# %%
df = pd.DataFrame(data)
df
# Out:
#   name  eng  hindi
# 0    a    8      2
# 1    b    7      3
# 2    c    5      4
# 3    d    8      5
# 4    a    8      2
# 5    c    5      6

# %% [markdown]
# #### Removing duplicate data

# %%
df.drop_duplicates()
# Out:
#   name  eng  hindi
# 0    a    8      2
# 1    b    7      3
# 2    c    5      4
# 3    d    8      5
# 5    c    5      6

# %%
df.drop_duplicates(inplace=True) # changing the permanent save of duplicates in your original data

# %%
df
# Out:
#   name  eng  hindi
# 0    a    8      2
# 1    b    7      3
# 2    c    5      4
# 3    d    8      5
# 5    c    5      6

# %%
dataset = pd.read_csv('loan_test.csv')
dataset.head(5)
# Out:
#   Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0   Male     Yes          0      Graduate            No            572000
# 1   Male     Yes          1      Graduate            No            307600
# 2   Male     Yes          2      Graduate            No            500000
# 3   Male     Yes          2      Graduate            No            234000
# 4   Male      No          0  Not Graduate            No            327600
#
#    Coapplicant_Income  Loan_Amount   Term  Credit_History   Area
# 0                   0     11000000  360.0             1.0  Urban
# 1              150000     12600000  360.0             1.0  Urban
# 2              180000     20800000  360.0             1.0  Urban
# 3              254600     10000000  360.0             NaN  Urban
# 4                   0      7800000  360.0             1.0  Urban

# %%
dataset.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 362    False
# 363    False
# 364    False
# 365    False
# 366    False
# Length: 367, dtype: bool

# %%
dataset.shape
# Out:
# (367, 11)

# %%
dataset.drop_duplicates(inplace=True)

# %%
dataset.shape
# Out:
# (366, 11)

# %% [markdown]
# #### If there is any change observe in shape, it means there was a duplicate values present in our dataset which got deleted .
# #### As you can see here, there is  change in shape of dataset by 1 value from 367 to 366 , there was one dupicate values was present in our dataset which get deleted now.
