# %% [markdown]
# ![WhatsApp Image 2024-12-04 at 19.29.03_94a06006.jpg](attachment:de94f487-6c5a-4bbd-b16a-37a59ba873c3.jpg)

# %% [markdown]
# ###
# Naïve Bayes Classifier Algorithm
# 👉Naïve Bayes algorithm is a supervised learning algorithm, which is based on Bayes theorem and used for solving classification problems.
#
# 👉It is mainly used in text classification that includes a high-dimensional training dataset.
# #### Naïve Bayes Classifier is one of the simple and most effective Classification algorithms which helps in building the fast machine learning models that can make quick predictions.
# 👉It is a probabilistic classifier, which means it predicts on the basis of the probability of an object.
#
# 👉Some popular examples of Naïve Bayes Algorithm are spam filtration, Sentimental analysis, and classifying articles.

# %% [markdown]
# ![Naive byes - Yahoo India Image Search results - Google Chrome 04-12-2024 19_13_11.png](attachment:152b6235-8552-40d1-af6e-9a50154ebc4d.png)

# %% [markdown]
# ![Naive byes - Yahoo India Image Search results - Google Chrome 04-12-2024 19_13_35.png](attachment:2ad548ba-a0dd-4ea5-9080-30c64ae76aea.png)

# %% [markdown]
# ![WhatsApp Image 2024-12-04 at 19.41.25_a2faa061.jpg](attachment:8d94119a-2b51-4819-9762-701d0ff086e2.jpg)

# %% [markdown]
# ![WhatsApp Image 2024-12-04 at 19.45.50_6dfbc185.jpg](attachment:f59241ef-537d-4a9b-86ce-223591bbc26e.jpg)

# %% [markdown]
# ![WhatsApp Image 2024-12-04 at 19.45.50_d475e6d3.jpg](attachment:0843d23e-282d-4ebd-9019-13269235c1ad.jpg)

# %% [markdown]
# ![WhatsApp Image 2024-12-04 at 19.45.50_2e49ccde.jpg](attachment:580f4ab0-7fd9-4ebc-948a-d027c0e1bcdb.jpg)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset = pd.read_csv('student_clustering.csv')
dataset.head(5)
# Out:
#    cgpa  iq  placement
# 0  5.14  83          0
# 1  5.28  83          0
# 2  5.01  83          0
# 3  5.44  84          0
# 4  5.34  85          0

# %%
dataset.isnull().sum()
# Out:
# cgpa         0
# iq           0
# placement    0
# dtype: int64

# %%
sns.scatterplot(x='cgpa',y='iq',data=dataset,hue='placement')
plt.show()

# %%
x= dataset.iloc[:,:-1]
y= dataset['placement']

# %%
# now splitting of data into training and testing
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
# check our data is in normal distribution or not
sns.kdeplot(data=dataset['iq'])
plt.show()

# %%
# our data is not in normal distribution, now we have to select desire model as compared to our data.....

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB

# %% [markdown]
# ### Gaussian NB model

# %%
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
gnb.score(x_test,y_test)*100 , gnb.score(x_train,y_train)*100
# Out:
# (90.0, 87.5)

# %%
gnb.predict([[5.28,	83]])
# Out:
# C:\Users\asmas\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
gnb.predict([[5.69,	109]])
# Out:
# C:\Users\asmas\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
# Gausian predict good accuracy

# %% [markdown]
# ### Multinomial NB model

# %%
mnb = MultinomialNB()
mnb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
mnb.score(x_test,y_test)*100 , mnb.score(x_train,y_train)*100
# Out:
# (52.5, 58.75)

# %% [markdown]
# ### Bernoulli NB model

# %%
bnb = BernoulliNB()
bnb.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
bnb.score(x_test,y_test)*100 , bnb.score(x_train,y_train)*100
# Out:
# (52.5, 58.75)

# %% [markdown]
# #### Berboulli NB model Accuracy is good as compared to all

# %% [markdown]
# ### GNB Decision Region Graph

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=gnb)
plt.show()
# Out:
# C:\Users\asmas\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### MNB Decision Region Graph

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=mnb)
plt.show()
# Out:
# C:\Users\asmas\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### BNB Decision Region Graph

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=bnb)
plt.show()
# Out:
# C:\Users\asmas\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but BernoulliNB was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Advantages of Naïve Bayes Classifier:
# * Naïve Bayes is one of the fast and easy ML algorithms to predict a class of datasets.
# * It can be used for Binary as well as Multi-class Classifications.
# * It performs well in Multi-class predictions as compared to the other Algorithms.
# * It is the most popular choice for text classification problems.
#
# ## Disadvantages of Naïve Bayes Classifier:
# * Naive Bayes assumes that all features are independent or unrelated, so it cannot learn  the relationship between features.
#
# ## Applications of Naïve Bayes Classifier:
# * It is used for Credit Scoring.
# * It is used in medical data classification.
# * It can be used in real-time predictions because Naïve Bayes Classifier is an eager learner.
# * It is used in Text classification such as Spam filtering and Sentiment analysis.
