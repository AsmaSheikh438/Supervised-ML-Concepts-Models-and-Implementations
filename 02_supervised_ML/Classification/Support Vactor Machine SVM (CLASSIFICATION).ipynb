# %% [markdown]
# ### Support Vector Machine (SVM): (CLASSIFICATION)
# * SVM is one of the most popular Supervised Learning Algorithms, which used for both Regression and Classification problems.
# * The goal of the SVM algorithm is to create the best line or decision boundary that can segregate n-dimensional space into classes so that we can easily     put the new data point in the correct category in the future. This best decision boundary is called a hyperplane.
#
# * SVM chooses the extreme points/vectors that help in creating the hyperplane. These extreme cases are called as support vectors, and hence algorithm is     termed as Support Vector Machine. Consider the below diagram in which there are two different categories that are classified using a decision boundary     or hyperplane:

# %% [markdown]
# ![support vector machine in machine learning - Yahoo India Image Search results - Google Chrome 07-12-2024 13_15_32.png](attachment:71bddef5-2f53-4bbd-8042-15f0929bb934.png)

# %% [markdown]
# ![WhatsApp Image 2024-12-07 at 13.16.48_20ecc1e1.jpg](attachment:2f3dafb6-213d-4a93-9eed-e849d940addd.jpg)

# %% [markdown]
# ### Example:
# SVM can be understood with the example that we have used in the KNN classifier. Suppose we see a strange cat that also has some features of dogs, so if we want a model that can accurately identify whether it is a cat or dog, so such a model can be created by using the SVM algorithm. We will first train our model with lots of images of cats and dogs so that it can learn about different features of cats and dogs, and then we test it with this strange creature. So as support vector creates a decision boundary between these two data (cat and dog) and choose extreme cases (support vectors), it will see the extreme case of cat and dog. On the basis of the support vectors, it will classify it as a cat. Consider the below diagram:

# %% [markdown]
# ![support vector machine in machine learning - Yahoo India Image Search results - Google Chrome 07-12-2024 13_24_32.png](attachment:29e44b65-3ef2-4d5a-aee7-9e3e7a43e5b7.png)

# %% [markdown]
# ![support vector machine in machine learning - Yahoo India Image Search results - Google Chrome 07-12-2024 13_25_38.png](attachment:34064669-c3c8-46cf-bddc-439314e704b2.png)

# %% [markdown]
# ![WhatsApp Image 2024-12-07 at 13.54.57_bd392c3f.jpg](attachment:b3c6b823-5185-496e-a1b7-ed9fe146c454.jpg)

# %% [markdown]
# ![support vector machine in machine learning - Yahoo India Image Search results - Google Chrome 07-12-2024 13_27_00.png](attachment:cef3026f-b27e-4ad2-82c8-969a619da288.png)

# %% [markdown]
# ![support vector machine in machine learning - Yahoo India Image Search results - Google Chrome 07-12-2024 13_28_53.png](attachment:e2d43053-a2cc-45e6-af52-494602c5bdc1.png)

# %% [markdown]
# ![support vector machine in machine learning - Yahoo India Image Search results - Google Chrome 07-12-2024 13_30_26.png](attachment:fc2b63bd-507a-4623-8533-fdd23b1219a7.png)

# %% [markdown]
# ![Support Vector Machine (SVM) Algorithm - Javatpoint - Google Chrome 07-12-2024 13_31_44.png](attachment:8546b60e-02a9-49f5-860f-633d105caa4e.png)

# %% [markdown]
# ![Support Vector Machine (SVM) Algorithm - Javatpoint - Google Chrome 07-12-2024 13_31_55.png](attachment:cb4719c1-e9a4-4a10-8ab7-5a0e476f74a3.png)

# %% [markdown]
# ![Support Vector Machine (SVM) Algorithm - Javatpoint - Google Chrome 07-12-2024 13_32_11.png](attachment:ff584a3a-d88e-48f3-86d6-eb210cbe2a57.png)

# %% [markdown]
# ![Support Vector Machine (SVM) Algorithm - Javatpoint - Google Chrome 07-12-2024 13_32_29.png](attachment:5c379bb6-50d7-4392-99d0-cee4eca98995.png)

# %% [markdown]
# ![kernel function in svm - Yahoo India Image Search results - Google Chrome 07-12-2024 14_02_13.png](attachment:aa54a057-6276-4b26-a2df-cce776a1eb7b.png)

# %% [markdown]
# ### SVM CLassification (PRACTICAL)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('placement-dataset.csv')
dataset.head(5)
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0    0
# cgpa          0
# iq            0
# placement     0
# dtype: int64

# %%
# checking distribution of data
sns.scatterplot(x='cgpa',y='iq',data=dataset, hue='placement')
plt.show()

# %%
x= dataset.iloc[:,:-1]
y= dataset['placement']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=20)

# %%
sv =  SVC(kernel='linear')
sv.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
from sklearn.svm import SVC

# %%
sv.score(x_test,y_test)*100
# Out:
# 90.0

# %%
# chceking data is overfitted or not
sv.score(x_train,y_train)*100
# Out:
# 93.75

# %%
# model is overfitted

# %%
# changed random state to = 20

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=sv)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=sv)
#       2 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlxtend\plotting\decision_regions.py:204, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     202 if dim > 2:
#     203     if filler_feature_values is None:
# --> 204         raise ValueError(
#     205             "Filler values must be provided when "
#     206             "X has more than 2 training features."
#     207         )
#     209     if filler_feature_ranges is not None:
# ...
