# %% [markdown]
# ## Linear Regression Algorithms :
# ### ( Simple Linear Regression )
# simple linear regression will apply when we have only 1 INPUT feature i.e, ( 1 independent feature)

# %% [markdown]
# #### Defination:
# Simple Linear Regression is a Type of Regression Algorithms that models the relationship between a dependent variable and a single independent variable.

# %% [markdown]
# #### EXAMPLE

# %% [markdown]
# ![regression analysis in machine learning - Yahoo India Image Search results - Google Chrome 30-11-2024 11_51_20.png](attachment:b337b8d5-5710-49b7-bafe-ecc10a4ad353.png)

# %% [markdown]
# ![regression analysis in machine learning - Yahoo India Image Search results - Google Chrome 30-11-2024 11_55_00.png](attachment:e3c318a1-3cae-4219-8213-1732e8a84fea.png)

# %% [markdown]
# ![WhatsApp Image 2024-11-30 at 12.02.35_794f3602.jpg](attachment:5e611257-a803-4647-a5e2-e3b2ff40a2ff.jpg)

# %% [markdown]
# ### Y = MX + C
# ##### Y = dependent variable
# ##### X = Independent variable
# ##### M = slope/gradient/coefficient
# ##### C = Intercept

# %% [markdown]
# ### Practical on simple Linear Regression

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv('salary_dataset.csv')
dataset.head(5)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
X= dataset['YearsExperience']

# %%
# seprate dependent and independent variable
X = dataset['YearsExperience']
X.ndim
# Out:
# 1

# %%
# here data is present in 1 dimention so we always have to change our data in 2 dimention.
# we have to apply only [[ ]] to change its dimention into 2 or 3 [[[ ]]]
X = dataset[['YearsExperience']]
X.ndim
# Out:
# 2

# %%
# dimention changed

# %%
X = dataset[['YearsExperience']]
Y = dataset['Salary']  # will be in 1 dimention

# %%
# now we have to see our graph will follow linearity or not
plt.figure(figsize=(5,3))
sns.scatterplot(x='YearsExperience',y='Salary',data = dataset)
plt.show()

# %%
# now splitting of data into training and testing
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# our model is trained now

# %%
# Now, our model is ready to make predictions now when we give any data to this model it will give predictions

# %%
# we can give our model input data and see it showing nearest output or not
1.2 , 39344.0
# Out:
# (1.2, 39344.0)

# %%
# testing
lr.predict([[1.2]])
# Out:
# C:\Users\asmas\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([35688.77986711])

# %%
# this is the good prediction

# %%
# But when we have to check our model is giving good prediction or not , we have to check ACCURACY SCORE

# %%
lr.score(X_test,Y_test)*100
# Out:
# 90.24461774180497

# %%
# model is giving 90% Accuracy

# %%
y_prd = lr.predict(X)

# %%
# now we will create prediction line in graph
plt.figure(figsize=(5,4))
sns.scatterplot(x='YearsExperience',y='Salary',data = dataset)
plt.plot(dataset['YearsExperience'],y_prd,c='red')
plt.legend(['org data','predict line'])
plt.savefig('predect.jpg')
plt.show()
